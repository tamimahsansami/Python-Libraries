# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,50)
print(x)
# Out:
# [32 28 37 40 14 36 28 19 45 38 35 22 29 23 38 22 18 11 51 21 35 46 24 31
#  54 20 35 24 41 40 40 48 55 15 52 11 44 37 24 10 32 40 48 47 32 44 23 55
#  33 12]

# %%
a=[32, 28, 37, 40, 14, 36, 28, 19, 45, 38, 35, 22, 29, 23, 38, 22, 18, 11, 51, 21, 35, 46, 24, 31,
 54, 20, 35, 24, 41, 40, 40, 48, 55, 15, 52, 11, 44 ,37, 24, 10, 32, 40, 48, 47, 32 ,44, 23, 55,
 33, 12]

plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

plt.hist(a,color="r",edgecolor="b")
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

l=[10,20,30,40,50,60]

plt.hist(a,color="r",bins=l,edgecolor="b")     #how much data in 10-20-30-40-50-60
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

plt.hist(a,"auto",(0,100),edgecolor="b")
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

plt.hist(a,color="r",edgecolor="b",cumulative=-1)   #make it reverse
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

plt.hist(a,color="r",edgecolor="b",bottom=10)    #start with 10
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

plt.hist(a,color="r",edgecolor="b",histtype="step")
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

plt.hist(a,color="r",edgecolor="b",orientation="horizontal")
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

l=[10,20,30,40,50,60]

plt.hist(a,color="r",bins=l,edgecolor="b",rwidth=.9)     #how much data in 10-20-30-40-50-60
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

l=[10,20,30,40,50,60]

plt.hist(a,color="b",bins=l,edgecolor="r",log=True)     #how much data in 10-20-30-40-50-60
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

l=[10,20,30,40,50,60]

plt.axvline(25,color="y",label="line")
plt.hist(a,color="m",bins=l,edgecolor="b",label="random")   #how much data in 10-20-30-40-50-60
plt.legend()
plt.show()

# %%
plt.xlabel("X AXIS",fontsize=15)
plt.ylabel("Y AXIS",fontsize=15)
plt.title("RANDOM FILE")

l=[10,20,30,40,50,60]

plt.hist(a,color="r",bins=l,edgecolor="b")     #how much data in 10-20-30-40-50-60
plt.grid()   #print it before the show function
plt.show()
